# %%
import pandas as pd

# %%
df = pd.read_csv('FeaturesWithLabels (1).csv')

# %%
df
# Out:
#              RID survival_label  Longest.Diameter..mm.  \
# 0          R0004           Long                  45.50
# 1          R0013           Long                  41.82
# 2          R0017           Long                  18.95
# 3          R0018          Short                  35.04
# 4          R0019          Short                  31.87
# 5   QIN-LSC-0009          Short                  22.07
# 6          R0022          Short                  30.02
# 7   QIN-LSC-0014          Short                  28.98
# 8          R0033          Short                  24.21
# 9          R0052          Short                  44.08
# 10         R0056           Long                  25.11
# 11         R0064           Long                  36.61
# 12         R0065          Short                  45.41
# 13         R0077           Long                  11.10
# 14         R0079          Short                  24.15
# 15         R0080          Short                  42.25
# ...

# %%
df2 = df[['RID', 'survival_label']]

# %%
df2
# Out:
#              RID survival_label
# 0          R0004           Long
# 1          R0013           Long
# 2          R0017           Long
# 3          R0018          Short
# 4          R0019          Short
# 5   QIN-LSC-0009          Short
# 6          R0022          Short
# 7   QIN-LSC-0014          Short
# 8          R0033          Short
# 9          R0052          Short
# 10         R0056           Long
# 11         R0064           Long
# 12         R0065          Short
# 13         R0077           Long
# 14         R0079          Short
# 15         R0080          Short
# 16         R0086           Long
# 17         R0098          Short
# 18         R0100          Short
# 19         R0102           Long
# 20         R0108          Short
# 21         R0117          Short
# 22         R0126          Short
# 23         R0127          Short
# 24         R0144          Short
# 25         R0146           Long
# 26         R0150           Long
# 27         R0166           Long
# ...
